# %%
from TB.c import *
# Out:
# import os
# import re
# import shutil
# import logging
#
# import pandas as pd
# import numpy as np
#
# import matplotlib
#
# from matplotlib import pylab, mlab
# from matplotlib import pyplot as plt
# import matplotlib as mpl
#
# from IPython.core.pylabtools import figsize, getfigs
#
# from datetime import date
# from os.path import isdir, isfile, basename, dirname, join
# from time import sleep
# from glob import glob
# from pathlib import Path as P
# from tqdm.notebook import tqdm
#
# from pylab import *
# from numpy import *
#
# import seaborn as sns
# import plotly.express as px
#
# from .plotting import savefig as sf
# from .plotting import (
#     plot_roc,
#     plot_random_roc,
#     plot_diagonal,
#     plot_hlines,
#     plot_vlines,
#     heatmap,
#     legend_outside,
#     plot_dendrogram,
# )
#
#
# plt.rcParams["figure.facecolor"] = "w"
# plt.rcParams["figure.dpi"] = 150
#
# pd.options.display.max_colwidth = 100
# pd.options.display.max_columns = 100
#
# ...

# %%
df = pd.read_parquet("/Users/sdrwacker/slurm-usage-history/daic/weekly_data/week_2024_W13.parquet")

# %%
df
# Out:
#              User     QOS                 Account               Partition  \
# 0      fabianfool    long              tnw-imphys                  imphys
# 1      fabianfool    long              tnw-imphys                  imphys
# 2      fabianfool    long              tnw-imphys                  imphys
# 3      fabianfool    long              tnw-imphys                  imphys
# 4          oturan    long  ewi-insy-prb-visionlab                 general
# ...           ...     ...                     ...                     ...
# 7716  sscherpbier  medium        ewi-insy-prb-dbl                 general
# 7717      maraghi   short  ewi-insy-prb-visionlab                    insy
# 7718      maraghi   short  ewi-insy-prb-visionlab  visionlab,insy,general
# 7719      maraghi   short  ewi-insy-prb-visionlab                    insy
# 7720      maraghi   short  ewi-insy-prb-visionlab  visionlab,insy,general
#
#                   Submit SubmitWeekDay SubmitYearWeek SubmitYearMonth  \
# ...

# %%
df.dtypes
# Out:
# User                       object
# QOS                        object
# Account                    object
# Partition                  object
# Submit             datetime64[ns]
# SubmitWeekDay              object
# SubmitYearWeek             object
# SubmitYearMonth            object
# StartWeekDay               object
# StartYearWeek              object
# StartYearMonth             object
# State                      object
# WaitingTime [h]           float64
# Elapsed [h]               float64
# Nodes                       int64
# NodeList                   object
# CPUs                        int64
# GPUs                        int64
# CPU-hours                 float64
# GPU-hours                 float64
# AveCPU                     object
# TotalCPU                   object
# AveDiskRead                object
# AveDiskWrite               object
# MaxRSS                     object
# dtype: object
